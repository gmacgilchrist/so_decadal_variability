# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
import so_decadal_variability.calc as socalc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fluxname='jra55'
oceanname='en4'
dg = 0.1
G = xr.open_dataset('../data/processed/'+fluxname+'_'+oceanname+'/G_'+str(dg)+'.nc')

# %%
dG = -1*G['total'].diff('gamman_bin')#.roll(gamman_bin=1,roll_coords=False)-G['total'].roll(gamman_bin=-1,roll_coords=False)

# %%
G['total'].mean('time').plot()

# %%
fig,ax=plt.subplots(figsize=(8,4))
ax.plot(socalc._annual(dG).transpose(),color='tab:blue',alpha=0.2)
ax.plot(dG.mean('time'),color='tab:blue')

# %%
upwelling = dG.where(dG<0,0).sum('gamman_bin')

# %%
# Out:
# <xarray.DataArray (time: 39, gamman_bin: 23)>
# array([[-5.35414342e+09,  4.56013663e+09,  1.27505685e+10,
#         -1.08054120e+10,  2.24148500e+09,  7.30000550e+09,
#          1.02754166e+10,  6.79478296e+09,  9.04763288e+08,
#          8.68198287e+09,  1.34708353e+10,  1.01818077e+10,
#         -1.64117071e+10, -1.44804763e+10, -9.85245344e+09,
#         -5.68274889e+09, -5.71869979e+09, -1.60633488e+09,
#          1.94977463e+09,  1.07719115e+09, -3.13593233e+08,
#         -8.86755203e+07, -1.70005609e+06],
#        [ 1.98831148e+09,  2.95905182e+09, -2.96892434e+09,
#          7.01839510e+09,  5.33456128e+09,  7.06056825e+09,
#          9.04575819e+09,  6.37550184e+09, -4.83415536e+09,
#          6.43786189e+09,  1.20387249e+10,  5.68213128e+09,
#         -1.80295639e+10, -9.94990760e+09, -5.61202774e+09,
#         -2.35608819e+09, -8.56503026e+09, -6.44249941e+08,
#         -2.38149225e+09,  2.69333959e+09,  4.93969549e+08,
#          4.92007697e+07,  2.55855700e+07],
# ...
